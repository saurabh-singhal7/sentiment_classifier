# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv("A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.csv", thousands=',')

# %%
df.head()
# Out:
#    State Code  District Code  Sub District Code  \
# 0           1              2                  3
# 1           0              0                  0
# 2           0              0                  0
# 3           0              0                  0
# 4           1              0                  0
#
#   India/ State/ Union Territory/ District/ Sub-district                Name  \
# 0                                                  4                      5
# 1                                              INDIA               INDIA @&
# 2                                              INDIA                INDIA $
# 3                                              INDIA                INDIA $
# 4                                              STATE     JAMMU & KASHMIR @&
#
#   Total/Rural/Urban  Inhabited  Uninhabited  Number of towns  \
# 0                 6          7            8                9
# 1             Total     597608        43324             7933
# ...

# %%
df.describe()
# Out:
#          State Code  District Code  Sub District Code      Inhabited  \
# count  19993.000000   19993.000000       19993.000000   19993.000000
# mean      19.238433     362.347672        3094.171610     239.128345
# std        8.675594     171.283385        6772.484185    6193.018585
# min        0.000000       0.000000           0.000000       0.000000
# 25%       10.000000     230.000000         990.000000       0.000000
# 50%       21.000000     376.000000        2623.000000      29.000000
# 75%       28.000000     533.000000        4288.000000     117.000000
# max       35.000000     640.000000       99999.000000  597608.000000
#
#         Uninhabited  Number of towns  Number of households       Persons  \
# count  19993.000000     19993.000000          1.999300e+04  1.999300e+04
# mean      17.336668         3.174761          9.983561e+04  4.845116e+05
# std      454.504412        82.226079          2.284218e+06  1.114486e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19993 entries, 0 to 19992
# Data columns (total 15 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   State Code                                             19993 non-null  int64
#  1   District Code                                          19993 non-null  int64
#  2   Sub District Code                                      19993 non-null  int64
#  3   India/ State/ Union Territory/ District/ Sub-district  19993 non-null  object
#  4   Name                                                   19993 non-null  object
#  5   Total/Rural/Urban                                      19993 non-null  object
#  6   Inhabited                                              19993 non-null  int64
#  7   Uninhabited                                            19993 non-null  int64
# ...

# %%
df.nunique()
# Out:
# State Code                                                  36
# District Code                                              641
# Sub District Code                                         5924
# India/ State/ Union Territory/ District/ Sub-district        5
# Name                                                      6057
# Total/Rural/Urban                                            4
# Inhabited                                                  894
# Uninhabited                                                224
# Number of towns                                             83
# Number of households                                     13100
# Persons                                                  13963
# Males                                                    13707
# Females                                                  13720
# Area(In sq. km)                                          12525
# Population per sq. km.                                    3940
# dtype: int64

# %%
df['State Code'].value_counts()
# Out:
# 28    3456
# 10    1719
# 21    1524
# 23    1179
# 27    1179
# 9     1152
# 19    1140
# 20     852
# 8      834
# 24     756
# 33     747
# 18     636
# 29     633
# 12     615
# 22     504
# 2      390
# 13     378
# 1      316
# 3      294
# 6      288
# 5      276
# 32     234
# 16     147
# 14     144
# 17     141
# 15     114
# 7      111
# 30      42
# 11      42
# 34      39
# 35      39
# 31      36
# 25      15
# 4        9
# 26       9
# 0        3
# Name: State Code, dtype: int64

# %%
df['District Code'].value_counts()
# Out:
# 554    201
# 538    195
# 553    192
# 545    183
# 539    180
#       ...
# 342      6
# 496      6
# 518      6
# 519      6
# 495      6
# Name: District Code, Length: 641, dtype: int64

# %%
df['India/ State/ Union Territory/ District/ Sub-district'].value_counts()
# Out:
# SUB-DISTRICT    17964
# DISTRICT         1920
# STATE             105
# INDIA               3
# 4                   1
# Name: India/ State/ Union Territory/ District/ Sub-district, dtype: int64

# %%
df.hist(bins=100, figsize=(20,15))
plt.show()

# %%
df.cov()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_21396\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                           State Code  District Code  Sub District Code  \
# State Code              7.526593e+01   1.453793e+03       1.414634e+04
# District Code           1.453793e+03   2.933800e+04       2.779229e+05
# Sub District Code       1.414634e+04   2.779229e+05       4.586654e+07
# Inhabited              -1.576178e+03  -4.901198e+04      -5.966639e+05
# Uninhabited            -1.290991e+02  -3.721457e+03      -4.410311e+04
# Number of towns        -1.224900e+01  -5.444800e+02      -5.853641e+03
# Number of households   -4.672531e+05  -1.797518e+07      -1.278633e+08
# Persons                -2.629992e+06  -9.180327e+07      -7.030316e+08
# ...

# %%
df.corr()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_21396\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         State Code  District Code  Sub District Code  \
# State Code                1.000000       0.978336           0.240767
# District Code             0.978336       1.000000           0.239586
# Sub District Code         0.240767       0.239586           1.000000
# Inhabited                -0.029336      -0.046205          -0.014226
# Uninhabited              -0.032741      -0.047803          -0.014328
# Number of towns          -0.017171      -0.038660          -0.010512
# Number of households     -0.023578      -0.045943          -0.008265
# Persons                  -0.027201      -0.048091          -0.009314
# ...

# %%
attributes = ["Inhabited", "Uninhabited", "Number of towns", "Number of households", "Males", "Females", "Area(In sq. km)", "Population per sq. km."]
scatter_matrix(df[attributes], figsize=(30,20))
# Out:
# array([[<Axes: xlabel='Inhabited', ylabel='Inhabited'>,
#         <Axes: xlabel='Uninhabited', ylabel='Inhabited'>,
#         <Axes: xlabel='Number of towns', ylabel='Inhabited'>,
#         <Axes: xlabel='Number of households', ylabel='Inhabited'>,
#         <Axes: xlabel='Males', ylabel='Inhabited'>,
#         <Axes: xlabel='Females', ylabel='Inhabited'>,
#         <Axes: xlabel='Area(In sq. km)', ylabel='Inhabited'>,
#         <Axes: xlabel='Population per sq. km.', ylabel='Inhabited'>],
#        [<Axes: xlabel='Inhabited', ylabel='Uninhabited'>,
#         <Axes: xlabel='Uninhabited', ylabel='Uninhabited'>,
#         <Axes: xlabel='Number of towns', ylabel='Uninhabited'>,
#         <Axes: xlabel='Number of households', ylabel='Uninhabited'>,
#         <Axes: xlabel='Males', ylabel='Uninhabited'>,
#         <Axes: xlabel='Females', ylabel='Uninhabited'>,
#         <Axes: xlabel='Area(In sq. km)', ylabel='Uninhabited'>,
# ...
