# %%
import pandas as pd

# %%
df = pd.read_csv("A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.csv")

# %%
df.head()
# Out:
#    State  Code District Code Sub District Code  \
# 0          1.0             2                 3
# 1          0.0           000             00000
# 2          0.0           000             00000
# 3          0.0           000             00000
# 4          1.0           000             00000
#
#   India/ State/ Union Territory/ District/ Sub-district                Name  \
# 0                                                  4                      5
# 1                                              INDIA               INDIA @&
# 2                                              INDIA                INDIA $
# 3                                              INDIA                INDIA $
# 4                                              STATE     JAMMU & KASHMIR @&
#
#   Total/\r\nRural/\r\nUrban Inhabited Uninhabited Number of towns  \
# 0                         6         7           8               9
# 1                     Total   597,608      43,324           7,933
# ...

# %%
df.dtypes
# Out:
# State  Code                                              float64
# District Code                                             object
# Sub District Code                                         object
# India/ State/ Union Territory/ District/ Sub-district     object
# Name                                                      object
# Total/\r\nRural/\r\nUrban                                 object
# Inhabited                                                 object
# Uninhabited                                               object
# Number of towns                                           object
# Number of households                                      object
# Persons                                                   object
# Males                                                     object
# Females                                                   object
# Area\r\n (In sq. km)                                     float64
# ...
